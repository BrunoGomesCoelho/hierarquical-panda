# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# For pretty printing pd tables
from pandas.api.types import is_numeric_dtype
from IPython.display import display, HTML


if __name__ == "__main__" and '__file__' not in globals():
    # Read definitions
    with open("file_instrument.txt", "r") as f:
        DATA_PATH = f.readline().split("=")[1].strip()
        SEP = f.readline().split("=")[1].strip()
        TARGET_COL = f.readline().split("=")[1].strip()
        train_name = f.readline().split("=")[1].strip()
        test_name = f.readline().split("=")[1].strip()
        try:
            skip_cols = f.readline().split("=")[1].strip()
        except:
            skip_cols = ""

    SPACE = "\n\n" + "---"*40 + "\n\n"

    # Any number less than this of nunique() will be considered as a categorical value
    #     encoded as numerical
    AMOUNT_TO_CONSIDER_CATEGORICAL = 50

# %%
if __name__ == "__main__" and '__file__' not in globals():
    train_df = pd.read_csv(f"{DATA_PATH}/{train_name}", sep=SEP)
    test_df = pd.read_csv(f"{DATA_PATH}/{test_name}", sep=SEP)

    merged_df = train_df.append(test_df, ignore_index=True, sort=False)
    
    TARGET_COLS =["level0", "level1", "level2"]
    TARGET_COL = "level0"
    merged_df[TARGET_COLS ] =  merged_df["class"].str.split(".",
                                                     expand=True).iloc[:, 1:]

# %%
def basic_describe(df, name="Train"):
    print(f"{name} shape: {df.shape} \n\n")
    print(f"Columns in {name}: ")
    print("\t", end="")
    print(*df.columns, sep="\n\t")
    print(SPACE)

    # NaNs
    nans = df.isna().sum()
    print(f"Amount of NaNs in total: {nans.sum()}")
    if nans.sum():
        print("NaNs per column:")
        display(HTML(pd.DataFrame(nans).to_html()))
    print(SPACE)

    # Basic Stats:
    print("Numerical Type stats:")
    display(HTML(df.describe().T.to_html()))
    print(SPACE)

    temp = df.select_dtypes(include="object")
    if len(temp.columns):
        print("Categorical Type stats:")
        display(HTML(temp.describe(include=['O']).T.to_html()))
        print(SPACE)

    for target_col in TARGET_COLS:
        print(f"Distribution of target: ")
        if df[target_col].dtype == "int64":
            temp = pd.DataFrame(df[target_col].value_counts(normalize=True))
            display(HTML(temp.to_html()))
            sns.countplot(df[target_col])
        elif df[target_col].dtype == "float64":
            sns.distplot(df[target_col], hist=False)
        else:
            sns.countplot(df[target_col])
            plt.xticks(rotation=90)
        plt.show()
        print(SPACE)


# Distplot
def my_distplot(df, col):
    if TARGET_COL:
        _, bins = np.histogram(df[col])
        g = sns.FacetGrid(df, hue=TARGET_COL, height=9)
        g.map(sns.distplot, col, bins=bins, hist=False)
        g.axes[0][0].legend()
    else:
        sns.distplot(df[col], hist=False)


def dist_columns(df):
    if TARGET_COL:
        cols = df.drop(columns=TARGET_COL).columns
    else:
        cols = df.columns

    for col in cols:
        nunique = df[col].nunique()
        if is_numeric_dtype(df[col]):
            print("\t\t", col)
            if nunique < AMOUNT_TO_CONSIDER_CATEGORICAL:
                if TARGET_COL:
                    sns.countplot(data=df, x=col, hue=TARGET_COL)
                else:
                    sns.countplot(data=df, x=col)
            else:
                my_distplot(df, col)
        else:
            print("\t\t", col)
            if nunique < 2*AMOUNT_TO_CONSIDER_CATEGORICAL:
                plt.figure(figsize=(16, 12))
                sns.countplot(data=df, x=col, hue=TARGET_COL)
                plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
                plt.xticks(rotation=90)

        plt.show()
        print(SPACE)


def boxplot_columns(df):
    if TARGET_COL:
        cols = df.drop(columns=TARGET_COL).columns
    else:
        cols = df.columns

    for col in cols:
        if is_numeric_dtype(df[col]):
            print("\t\t", col)
            nunique = df[col].nunique()
            if TARGET_COL:
                sns.boxplot(data=df, y=col, x=TARGET_COL)
            else:
                sns.boxplot(df[col])
            plt.xticks(rotation=90)
            plt.show()
            print(SPACE)


def correlation(df):
    numeric_cols = [x for x in df.columns if is_numeric_dtype(df[x])]
    plt.figure(figsize=(20, 15))
    sns.heatmap(df[numeric_cols].corr("spearman"), annot=True)
    plt.show()
    print(SPACE)

# %%
# Outliers
def calculate_outliers(our_df):
    # Remove NaNs otherwise functions dont work
    print("Remove any NaNs for outlier detection!\n")
    df = our_df.dropna()
    
    iqr_threshold = [1.5, 2, 2.5]
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1

    # For different threshold
    for thres in iqr_threshold:
        try:
            outliers_idx = ((df < (Q1 - thres*IQR)) | (df > (Q3 + thres*IQR))).any(axis=1)
            amount =  outliers_idx.sum()
            print(f"Considering column {thres}*IQR: \t we have {amount} ",
                  f"({(100*amount)/len(df)}%) of outliers")
        except Exception as error:
            print("Error - could not process all cols for IQR analysis.", 
                  "Maybe differente types?")
            print(error)
    
    print(SPACE)
        
    # For different columns
    thres = 1.5
    print(f"Consdiering {thres}*IQR, we have....\n")
    for col in df.columns:
        try:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            outliers_idx = ((df[col] < (Q1 - thres*IQR)) | (df[col] > (Q3 + thres*IQR)))
            amount =  outliers_idx.sum()
            if amount != 0:
                print(f"Considering {col} \t we have {amount} ",
                      f"({(100*amount)/len(df)}%) of outliers\n")
        except:
            print(f"Error - could not process col {col}")

# %% [markdown]
# - - -
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Basic Describe
#
# <br>

# %%
if __name__ == "__main__" and '__file__' not in globals():
    basic_describe(merged_df, "Train")
# Out:
# Train shape: (9419, 34)
#
#
# Columns in Train:
# 	mfcc1
# 	mfcc2
# 	mfcc3
# 	mfcc4
# 	mfcc5
# 	mfcc6
# 	mfcc7
# 	mfcc8
# 	mfcc9
# 	mfcc10
# 	mfcc11
# 	mfcc12
# 	mfcc13
# 	mfcc14
# 	mfcc15
# 	mfcc16
# 	mfcc17
# 	mfcc18
# 	mfcc19
# 	mfcc20
# 	mfcc21
# 	mfcc22
# 	mfcc23
# 	mfcc24
# 	mfcc25
# 	mfcc26
# 	mfcc27
# 	mfcc28
# 	mfcc29
# 	mfcc30
# 	class
# 	level0
# 	level1
# 	level2
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Amount of NaNs in total: 0
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Numerical Type stats:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>mfcc1</th>
#       <td>9419.0</td>
#       <td>-443.449454</td>
#       <td>133.321966</td>
#       <td>-899.941120</td>
#       <td>-540.230517</td>
#       <td>-443.967263</td>
#       <td>-346.763582</td>
#       <td>-49.476309</td>
#     </tr>
#     <tr>
#       <th>mfcc2</th>
#       <td>9419.0</td>
#       <td>67.040728</td>
#       <td>68.642638</td>
#       <td>-272.473208</td>
#       <td>17.897917</td>
#       <td>57.704608</td>
#       <td>118.999293</td>
#       <td>249.557050</td>
#     </tr>
#     <tr>
#       <th>mfcc3</th>
#       <td>9419.0</td>
#       <td>-21.225166</td>
#       <td>33.824445</td>
#       <td>-132.382566</td>
#       <td>-44.995646</td>
#       <td>-27.755638</td>
#       <td>-1.138133</td>
#       <td>98.096736</td>
#     </tr>
#     <tr>
#       <th>mfcc4</th>
#       <td>9419.0</td>
#       <td>4.921104</td>
#       <td>16.548039</td>
#       <td>-82.954470</td>
#       <td>-6.242990</td>
#       <td>4.626613</td>
#       <td>15.393690</td>
#       <td>72.031727</td>
#     </tr>
#     <tr>
#       <th>mfcc5</th>
#       <td>9419.0</td>
#       <td>-5.500639</td>
#       <td>16.028629</td>
#       <td>-61.213171</td>
#       <td>-16.411079</td>
#       <td>-6.682558</td>
#       <td>4.742730</td>
#       <td>57.187800</td>
#     </tr>
#     <tr>
#       <th>mfcc6</th>
#       <td>9419.0</td>
#       <td>-1.239704</td>
#       <td>14.510831</td>
#       <td>-55.196568</td>
#       <td>-11.028014</td>
#       <td>-2.228417</td>
#       <td>7.334383</td>
#       <td>63.169549</td>
#     </tr>
#     <tr>
#       <th>mfcc7</th>
#       <td>9419.0</td>
#       <td>-5.533772</td>
#       <td>14.260372</td>
#       <td>-59.676804</td>
#       <td>-14.497264</td>
#       <td>-6.187116</td>
#       <td>2.070766</td>
#       <td>56.133439</td>
#     </tr>
#     <tr>
#       <th>mfcc8</th>
#       <td>9419.0</td>
#       <td>-5.059702</td>
#       <td>14.001394</td>
#       <td>-53.269015</td>
#       <td>-13.692999</td>
#       <td>-6.097205</td>
#       <td>1.695231</td>
#       <td>69.418457</td>
#     </tr>
#     <tr>
#       <th>mfcc9</th>
#       <td>9419.0</td>
#       <td>-5.256820</td>
#       <td>14.140584</td>
#       <td>-63.088325</td>
#       <td>-13.434397</td>
#       <td>-6.561279</td>
#       <td>0.814561</td>
#       <td>64.489429</td>
#     </tr>
#     <tr>
#       <th>mfcc10</th>
#       <td>9419.0</td>
#       <td>-1.892083</td>
#       <td>15.764658</td>
#       <td>-72.248853</td>
#       <td>-11.218619</td>
#       <td>-3.633359</td>
#       <td>5.048039</td>
#       <td>66.630862</td>
#     </tr>
#     <tr>
#       <th>mfcc11</th>
#       <td>9419.0</td>
#       <td>-3.086579</td>
#       <td>15.455896</td>
#       <td>-52.290742</td>
#       <td>-11.983222</td>
#       <td>-4.420518</td>
#       <td>3.517767</td>
#       <td>66.361428</td>
#     </tr>
#     <tr>
#       <th>mfcc12</th>
#       <td>9419.0</td>
#       <td>-0.649589</td>
#       <td>15.502420</td>
#       <td>-48.609353</td>
#       <td>-9.749334</td>
#       <td>-2.339834</td>
#       <td>5.374181</td>
#       <td>67.807883</td>
#     </tr>
#     <tr>
#       <th>mfcc13</th>
#       <td>9419.0</td>
#       <td>-1.680385</td>
#       <td>14.824255</td>
#       <td>-52.214358</td>
#       <td>-10.233307</td>
#       <td>-3.190905</td>
#       <td>4.332524</td>
#       <td>61.822212</td>
#     </tr>
#     <tr>
#       <th>mfcc14</th>
#       <td>9419.0</td>
#       <td>-0.013755</td>
#       <td>14.152638</td>
#       <td>-44.320048</td>
#       <td>-8.178417</td>
#       <td>-2.072072</td>
#       <td>5.302260</td>
#       <td>70.585888</td>
#     </tr>
#     <tr>
#       <th>mfcc15</th>
#       <td>9419.0</td>
#       <td>-0.726243</td>
#       <td>13.894978</td>
#       <td>-46.144825</td>
#       <td>-8.399832</td>
#       <td>-2.395080</td>
#       <td>4.514119</td>
#       <td>61.753613</td>
#     </tr>
#     <tr>
#       <th>mfcc16</th>
#       <td>9419.0</td>
#       <td>0.578594</td>
#       <td>14.528452</td>
#       <td>-45.838260</td>
#       <td>-7.475042</td>
#       <td>-0.506870</td>
#       <td>5.812949</td>
#       <td>58.911384</td>
#     </tr>
#     <tr>
#       <th>mfcc17</th>
#       <td>9419.0</td>
#       <td>-0.487709</td>
#       <td>16.048875</td>
#       <td>-49.908425</td>
#       <td>-9.297821</td>
#       <td>-2.182727</td>
#       <td>4.713423</td>
#       <td>59.016531</td>
#     </tr>
#     <tr>
#       <th>mfcc18</th>
#       <td>9419.0</td>
#       <td>0.251265</td>
#       <td>16.147129</td>
#       <td>-52.458202</td>
#       <td>-8.485354</td>
#       <td>-1.397563</td>
#       <td>6.044369</td>
#       <td>58.541479</td>
#     </tr>
#     <tr>
#       <th>mfcc19</th>
#       <td>9419.0</td>
#       <td>0.465144</td>
#       <td>15.549048</td>
#       <td>-50.887936</td>
#       <td>-8.016428</td>
#       <td>-0.700879</td>
#       <td>7.130749</td>
#       <td>51.850683</td>
#     </tr>
#     <tr>
#       <th>mfcc20</th>
#       <td>9419.0</td>
#       <td>-0.222965</td>
#       <td>13.836256</td>
#       <td>-50.561945</td>
#       <td>-8.135339</td>
#       <td>-1.535286</td>
#       <td>5.773558</td>
#       <td>53.084720</td>
#     </tr>
#     <tr>
#       <th>mfcc21</th>
#       <td>9419.0</td>
#       <td>-0.394749</td>
#       <td>11.951297</td>
#       <td>-40.608719</td>
#       <td>-6.477532</td>
#       <td>-0.959983</td>
#       <td>4.765564</td>
#       <td>50.288029</td>
#     </tr>
#     <tr>
#       <th>mfcc22</th>
#       <td>9419.0</td>
#       <td>0.714986</td>
#       <td>11.441329</td>
#       <td>-39.354850</td>
#       <td>-5.129110</td>
#       <td>0.196442</td>
#       <td>5.811154</td>
#       <td>49.353362</td>
#     </tr>
#     <tr>
#       <th>mfcc23</th>
#       <td>9419.0</td>
#       <td>-0.076337</td>
#       <td>10.632230</td>
#       <td>-42.345345</td>
#       <td>-5.916974</td>
#       <td>-0.958033</td>
#       <td>4.609270</td>
#       <td>47.110514</td>
#     </tr>
#     <tr>
#       <th>mfcc24</th>
#       <td>9419.0</td>
#       <td>0.731416</td>
#       <td>10.364382</td>
#       <td>-40.189237</td>
#       <td>-5.027329</td>
#       <td>-0.500122</td>
#       <td>5.438296</td>
#       <td>45.440534</td>
#     </tr>
#     <tr>
#       <th>mfcc25</th>
#       <td>9419.0</td>
#       <td>1.018887</td>
#       <td>10.192693</td>
#       <td>-35.634618</td>
#       <td>-4.688955</td>
#       <td>-0.049133</td>
#       <td>5.886361</td>
#       <td>38.390549</td>
#     </tr>
#     <tr>
#       <th>mfcc26</th>
#       <td>9419.0</td>
#       <td>0.275015</td>
#       <td>11.025938</td>
#       <td>-46.382068</td>
#       <td>-6.245090</td>
#       <td>-1.141631</td>
#       <td>6.591005</td>
#       <td>38.769873</td>
#     </tr>
#     <tr>
#       <th>mfcc27</th>
#       <td>9419.0</td>
#       <td>0.138908</td>
#       <td>11.568485</td>
#       <td>-39.252977</td>
#       <td>-6.560313</td>
#       <td>-1.465738</td>
#       <td>6.586099</td>
#       <td>42.814338</td>
#     </tr>
#     <tr>
#       <th>mfcc28</th>
#       <td>9419.0</td>
#       <td>1.100776</td>
#       <td>10.955137</td>
#       <td>-38.107253</td>
#       <td>-5.102894</td>
#       <td>-0.027770</td>
#       <td>6.896422</td>
#       <td>39.617680</td>
#     </tr>
#     <tr>
#       <th>mfcc29</th>
#       <td>9419.0</td>
#       <td>0.452022</td>
#       <td>8.801434</td>
#       <td>-25.389817</td>
#       <td>-4.668010</td>
#       <td>-0.468313</td>
#       <td>5.777387</td>
#       <td>31.303422</td>
#     </tr>
#     <tr>
#       <th>mfcc30</th>
#       <td>9419.0</td>
#       <td>0.604207</td>
#       <td>7.008364</td>
#       <td>-27.810307</td>
#       <td>-3.197740</td>
#       <td>0.050187</td>
#       <td>4.187418</td>
#       <td>30.152517</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Categorical Type stats:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>unique</th>
#       <th>top</th>
#       <th>freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>class</th>
#       <td>9419</td>
#       <td>31</td>
#       <td>Instrument.Aerophone.Wood.Flute</td>
#       <td>1029</td>
#     </tr>
#     <tr>
#       <th>level0</th>
#       <td>9419</td>
#       <td>5</td>
#       <td>Aerophone</td>
#       <td>7341</td>
#     </tr>
#     <tr>
#       <th>level1</th>
#       <td>9419</td>
#       <td>10</td>
#       <td>Wood</td>
#       <td>4257</td>
#     </tr>
#     <tr>
#       <th>level2</th>
#       <td>9419</td>
#       <td>31</td>
#       <td>Flute</td>
#       <td>1029</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Distribution of target:
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Distribution of target:
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Distribution of target:
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - - -
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Distplots

# %%
if __name__ == "__main__" and '__file__' not in globals():
    dist_columns(merged_df)
# Out:
# 		 mfcc1
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc2
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc3
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc4
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc5
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc6
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc7
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc8
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc9
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc10
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc11
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc12
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc13
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc14
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc15
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc16
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc17
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc18
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc19
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc20
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc21
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc22
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc23
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc24
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc25
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc26
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc27
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc28
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc29
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc30
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 class
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 level1
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 level2
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - - -
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Boxplots

# %%
if __name__ == "__main__" and '__file__' not in globals():
    boxplot_columns(merged_df)
# Out:
# 		 mfcc1
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc2
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc3
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc4
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc5
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc6
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc7
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc8
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc9
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc10
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc11
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc12
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc13
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc14
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc15
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc16
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc17
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc18
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc19
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc20
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc21
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc22
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc23
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc24
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc25
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc26
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc27
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc28
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc29
# ------------------------------------------------------------------------------------------------------------------------
#
#
# 		 mfcc30
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - - -
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ## Outliers

# %%
if __name__ == "__main__" and '__file__' not in globals():
    calculate_outliers(merged_df)
# Out:
# Remove any NaNs for outlier detection!
#
# Error - could not process all cols for IQR analysis. Maybe differente types?
# Could not operate array([nan, nan, nan, nan]) with block values '<' not supported between instances of 'str' and 'float'
# Error - could not process all cols for IQR analysis. Maybe differente types?
# Could not operate array([nan, nan, nan, nan]) with block values '<' not supported between instances of 'str' and 'float'
# Error - could not process all cols for IQR analysis. Maybe differente types?
# Could not operate array([nan, nan, nan, nan]) with block values '<' not supported between instances of 'str' and 'float'
#
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# Consdiering 1.5*IQR, we have....
#
# Considering mfcc1 	 we have 2  (0.02123367661110521%) of outliers
#
# Considering mfcc2 	 we have 16  (0.1698694128888417%) of outliers
#
# Considering mfcc3 	 we have 317  (3.3655377428601763%) of outliers
#
# Considering mfcc4 	 we have 91  (0.9661322858052872%) of outliers
#
# Considering mfcc5 	 we have 102  (1.082917507166366%) of outliers
#
# Considering mfcc6 	 we have 206  (2.187068690943837%) of outliers
#
# Considering mfcc7 	 we have 335  (3.5566408323601233%) of outliers
#
# Considering mfcc8 	 we have 390  (4.140566939165517%) of outliers
#
# Considering mfcc9 	 we have 583  (6.18961673213717%) of outliers
#
# Considering mfcc10 	 we have 553  (5.871111582970592%) of outliers
#
# Considering mfcc11 	 we have 645  (6.8478607070814315%) of outliers
#
# Considering mfcc12 	 we have 704  (7.474254167109035%) of outliers
#
# Considering mfcc13 	 we have 674  (7.1557490179424565%) of outliers
#
# Considering mfcc14 	 we have 652  (6.9221785752203%) of outliers
#
# Considering mfcc15 	 we have 729  (7.73967512474785%) of outliers
#
# Considering mfcc16 	 we have 844  (8.9606115298864%) of outliers
#
# Considering mfcc17 	 we have 975  (10.351417347913792%) of outliers
#
# Considering mfcc18 	 we have 907  (9.629472343136214%) of outliers
#
# Considering mfcc19 	 we have 716  (7.601656226775666%) of outliers
#
# Considering mfcc20 	 we have 556  (5.902962097887249%) of outliers
#
# Considering mfcc21 	 we have 769  (8.164348656969954%) of outliers
#
# Considering mfcc22 	 we have 683  (7.25130056269243%) of outliers
#
# Considering mfcc23 	 we have 604  (6.412570336553774%) of outliers
#
# Considering mfcc24 	 we have 539  (5.722475846692855%) of outliers
#
# Considering mfcc25 	 we have 573  (6.083448349081643%) of outliers
#
# Considering mfcc26 	 we have 211  (2.2401528824716%) of outliers
#
# Considering mfcc27 	 we have 304  (3.2275188448879923%) of outliers
#
# Considering mfcc28 	 we have 383  (4.066249071026649%) of outliers
#
# Considering mfcc29 	 we have 190  (2.017199278054995%) of outliers
#
# Considering mfcc30 	 we have 495  (5.25533496124854%) of outliers
#
# Error - could not process col class
# Error - could not process col level0
# Error - could not process col level1
# Error - could not process col level2

# %% [markdown]
# ## Correlations

# %%
if __name__ == "__main__" and '__file__' not in globals():
    correlation(merged_df)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
